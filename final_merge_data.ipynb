# %% [markdown]
# <a href="https://colab.research.google.com/github/PIYUJIN/Business-Analytics_term-project/blob/main/final_merge_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# main data + Gov_Spnsorship

# %%
main_2015 = pd.read_excel( '/content/sample_data/main_2015.xlsx', engine='openpyxl')
main_2016 = pd.read_excel( '/content/sample_data/main_2016.xlsx', engine='openpyxl')
main_2017 = pd.read_excel( '/content/sample_data/main_2017.xlsx', engine='openpyxl')
main_2018 = pd.read_excel( '/content/sample_data/main_2018.xlsx', engine='openpyxl')
main_2019 = pd.read_excel( '/content/sample_data/main_2019.xlsx', engine='openpyxl')
main_2020 = pd.read_excel( '/content/sample_data/main_2020.xlsx', engine='openpyxl')
main_2021 = pd.read_excel( '/content/sample_data/main_2021.xlsx', engine='openpyxl')

# %%
main_2015
# Out:
#          연도        학교명  시도    대계열    중계열       학과명  모집인원_학부_계  지원자_전체_계  \
# 0      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    국어국문학과         38       238
# 1      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    중어중문학과         27       154
# 2      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    영어영문학과         38       193
# 3      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    독어독문학과         23       118
# 4      2015    강릉원주대학교  강원   인문계열   인문과학       사학과         27       174
# ...     ...        ...  ..    ...    ...       ...        ...       ...
# 11879  2015  한국전통문화대학교  충남   인문계열   인문과학     보존과학과         21       139
# 11880  2015  한국전통문화대학교  충남   공학계열     건축    전통건축학과         21       126
# 11881  2015  한국전통문화대학교  충남   공학계열     건축    전통조경학과         21       100
# 11882  2015  한국전통문화대학교  충남  예체능계열   응용예술  전통미술공예학과         42       142
# 11883  2015  한국전통문화대학교  충남    NaN    NaN    소속학과없음          0         0
#
#        입학자_전체_계
# 0            37
# 1            26
# 2            36
# 3            23
# ...

# %%
main_2015['Gov_Spnsorship'] = 0
main_2016['Gov_Spnsorship'] = 0
main_2017['Gov_Spnsorship'] = 0
main_2018['Gov_Spnsorship'] = 0
main_2019['Gov_Spnsorship'] = 0
main_2020['Gov_Spnsorship'] = 0
main_2021['Gov_Spnsorship'] = 0

# %%
main_2015.columns
# Out:
# Index(['연도', '학교명', '시도', '대계열', '중계열', '학과명', '모집인원_학부_계', '지원자_전체_계',
#        '입학자_전체_계', 'Gov_Spnsorship'],
#       dtype='object')

# %%
main_2015['awareness'] = 0
main_2016['awareness'] = 0
main_2017['awareness'] = 0
main_2018['awareness'] = 0
main_2019['awareness'] = 0
main_2020['awareness'] = 0
main_2021['awareness'] = 0

# %%
for i in range(len(main_2015)):
    target = main_2015.loc[i]
    if(target['중계열']=='경영ㆍ경제') :
        main_2015.loc[[i],['awareness']] = 10
    elif (target['중계열']=='사회과학') :
        main_2015.loc[[i],['awareness']] = 9
    elif (target['중계열']=='기계ㆍ금속') :
        main_2015.loc[[i],['awareness']] = 8
    elif (target['중계열']=='언어ㆍ문학') :
        main_2015.loc[[i],['awareness']] = 7
    elif (target['중계열']=='디자인') :
        main_2015.loc[[i],['awareness']] = 6
    elif (target['중계열']=='중등교육') :
        main_2015.loc[[i],['awareness']] = 5
    elif (target['중계열']=='생물ㆍ화학ㆍ환경') :
        main_2015.loc[[i],['awareness']] = 4
    elif (target['중계열']=='컴퓨터ㆍ통신') :
        main_2015.loc[[i],['awareness']] = 3
    elif (target['중계열']=='인문과학') :
        main_2015.loc[[i],['awareness']] = 2
    elif (target['중계열']=='간호') :
        main_2015.loc[[i],['awareness']] = 1
    else :
        main_2015.loc[[i],['awareness']] = 0

# %%
# for i in range(len(main_2015)):
#     target = main_2015.loc[i]
#     print(target)

# %%
main_2015
# Out:
#          연도        학교명  시도    대계열    중계열       학과명  모집인원_학부_계  지원자_전체_계  \
# 0      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    국어국문학과         38       238
# 1      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    중어중문학과         27       154
# 2      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    영어영문학과         38       193
# 3      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    독어독문학과         23       118
# 4      2015    강릉원주대학교  강원   인문계열   인문과학       사학과         27       174
# ...     ...        ...  ..    ...    ...       ...        ...       ...
# 11879  2015  한국전통문화대학교  충남   인문계열   인문과학     보존과학과         21       139
# 11880  2015  한국전통문화대학교  충남   공학계열     건축    전통건축학과         21       126
# 11881  2015  한국전통문화대학교  충남   공학계열     건축    전통조경학과         21       100
# 11882  2015  한국전통문화대학교  충남  예체능계열   응용예술  전통미술공예학과         42       142
# 11883  2015  한국전통문화대학교  충남    NaN    NaN    소속학과없음          0         0
#
#        입학자_전체_계  Gov_Spnsorship  awareness
# 0            37               0          7
# ...

# %%
for i in range(len(main_2016)):
    target = main_2016.loc[i]
    if(target['중계열']=='경영ㆍ경제') :
        main_2016.loc[[i],['awareness']] = 10
    elif (target['중계열']=='간호') :
        main_2016.loc[[i],['awareness']] = 9
    elif (target['중계열']=='언어ㆍ문학') :
        main_2016.loc[[i],['awareness']] = 8
    elif (target['중계열']=='중등교육') :
        main_2016.loc[[i],['awareness']] = 7
    elif (target['중계열']=='사회과학') :
        main_2016.loc[[i],['awareness']] = 6
    elif (target['중계열']=='디자인') :
        main_2016.loc[[i],['awareness']] = 5
    elif (target['중계열']=='기계ㆍ금속') :
        main_2016.loc[[i],['awareness']] = 4
    elif (target['중계열']=='생물ㆍ화학ㆍ환경') :
        main_2016.loc[[i],['awareness']] = 3
    elif (target['중계열']=='컴퓨터ㆍ통신') :
        main_2016.loc[[i],['awareness']] = 2
    elif (target['중계열']=='연극ㆍ영화') :
        main_2016.loc[[i],['awareness']] = 1
    else :
        main_2016.loc[[i],['awareness']] = 0

# %%
for i in range(len(main_2017)):
    target = main_2017.loc[i]
    if(target['중계열']=='언어ㆍ문학') :
        main_2017.loc[[i],['awareness']] = 10
    elif (target['중계열']=='경영ㆍ경제') :
        main_2017.loc[[i],['awareness']] = 9
    elif (target['중계열']=='간호') :
        main_2017.loc[[i],['awareness']] = 8
    elif (target['중계열']=='디자인') :
        main_2017.loc[[i],['awareness']] = 7
    elif (target['중계열']=='생물ㆍ화학ㆍ환경') :
        main_2017.loc[[i],['awareness']] = 6
    elif (target['중계열']=='기계ㆍ금속') :
        main_2017.loc[[i],['awareness']] = 5
    elif (target['중계열']=='사회과학') :
        main_2017.loc[[i],['awareness']] = 4
    elif (target['중계열']=='컴퓨터ㆍ통신') :
        main_2017.loc[[i],['awareness']] = 3
    elif (target['중계열']=='인문과학') :
        main_2017.loc[[i],['awareness']] = 2
    elif (target['중계열']=='중등교육') :
        main_2017.loc[[i],['awareness']] = 1
    else :
        main_2017.loc[[i],['awareness']] = 0

# %%
for i in range(len(main_2018)):
    target = main_2018.loc[i]
    if(target['중계열']=='경영ㆍ경제') :
        main_2018.loc[[i],['awareness']] = 10
    elif (target['중계열']=='사회과학') :
        main_2018.loc[[i],['awareness']] = 9
    elif (target['중계열']=='언어ㆍ문학') :
        main_2018.loc[[i],['awareness']] = 8
    elif (target['중계열']=='간호') :
        main_2018.loc[[i],['awareness']] = 7
    elif (target['중계열']=='무용ㆍ체육') :
       main_2018.loc[[i],['awareness']] = 6
    elif (target['중계열']=='디자인') :
        main_2018.loc[[i],['awareness']] = 5
    elif (target['중계열']=='인문과학') :
        main_2018.loc[[i],['awareness']] = 4
    elif (target['중계열']=='기계ㆍ금속') :
        main_2018.loc[[i],['awareness']] = 3
    elif (target['중계열']=='중등교육') :
        main_2018.loc[[i],['awareness']] = 2
    elif (target['중계열']=='컴퓨터ㆍ통신') :
        main_2018.loc[[i],['awareness']] = 1
    else :
        main_2018.loc[[i],['awareness']] = 0

# %%
for i in range(len(main_2019)):
    target = main_2019.loc[i]
    if(target['중계열']=='경영ㆍ경제') :
        main_2019.loc[[i],['awareness']] = 10
    elif (target['중계열']=='언어ㆍ문학') :
        main_2019.loc[[i],['awareness']] = 9
    elif (target['중계열']=='컴퓨터ㆍ통신') :
        main_2019.loc[[i],['awareness']] = 8
    elif (target['중계열']=='사회과학') :
        main_2019.loc[[i],['awareness']] = 7
    elif (target['중계열']=='디자인') :
        main_2019.loc[[i],['awareness']] = 6
    elif (target['중계열']=='인문과학') :
        main_2019.loc[[i],['awareness']] = 5
    elif (target['중계열']=='무용ㆍ체육') :
        main_2019.loc[[i],['awareness']] = 4
    elif (target['중계열']=='중등교육') :
        main_2019.loc[[i],['awareness']] = 3
    elif (target['중계열']=='간호') :
        main_2019.loc[[i],['awareness']] = 2
    elif (target['중계열']=='생물ㆍ화학ㆍ환경') :
        main_2019.loc[[i],['awareness']] = 1
    else :
        main_2019.loc[[i],['awareness']] = 0

# %%
main_2019
# Out:
#          연도        학교명  시도    대계열    중계열       학과명  모집인원_학부_계  지원자_전체_계  \
# 0      2019    강릉원주대학교  강원   인문계열  언어ㆍ문학    국어국문학과         36       187
# 1      2019    강릉원주대학교  강원   인문계열  언어ㆍ문학    중어중문학과         24       162
# 2      2019    강릉원주대학교  강원   인문계열  언어ㆍ문학    영어영문학과         32       145
# 3      2019    강릉원주대학교  강원   인문계열  언어ㆍ문학    독어독문학과         18       164
# 4      2019    강릉원주대학교  강원   인문계열   인문과학       사학과         19       149
# ...     ...        ...  ..    ...    ...       ...        ...       ...
# 12532  2019  한국전통문화대학교  충남   인문계열   인문과학    기타모집단위          2         0
# 12533  2019  한국전통문화대학교  충남   공학계열     건축    전통건축학과         21       154
# 12534  2019  한국전통문화대학교  충남   공학계열     건축    전통조경학과         16       105
# 12535  2019  한국전통문화대학교  충남  예체능계열   응용예술  전통미술공예학과         41       145
# 12536  2019  한국전통문화대학교  충남    NaN    NaN    소속학과없음          0         0
#
#        입학자_전체_계  Gov_Spnsorship  awareness
# 0            37               0          9
# ...

# %%
for i in range(len(main_2020)):
    target = main_2020.loc[i]
    if(target['중계열']=='컴퓨터ㆍ통신') :
        main_2020.loc[[i],['awareness']] = 10
    elif (target['중계열']=='경영ㆍ경제') :
        main_2020.loc[[i],['awareness']] = 9
    elif (target['중계열']=='생물ㆍ화학ㆍ환경') :
        main_2020.loc[[i],['awareness']] = 8
    elif (target['중계열']=='간호') :
        main_2020.loc[[i],['awareness']] = 7
    elif (target['중계열']=='디자인') :
        main_2020.loc[[i],['awareness']] = 6
    elif (target['중계열']=='사회과학') :
        main_2020.loc[[i],['awareness']] = 5
    elif (target['중계열']=='언어ㆍ문학') :
        main_2020.loc[[i],['awareness']] = 4
    elif (target['중계열']=='의료') :
        main_2020.loc[[i],['awareness']] = 3
    elif (target['중계열']=='화공') :
        main_2020.loc[[i],['awareness']] = 2
    elif (target['중계열']=='기계ㆍ금속') :
        main_2020.loc[[i],['awareness']] = 1
    else :
        main_2020.loc[[i],['awareness']] = 0

# %%
for i in range(len(main_2021)):
    target = main_2021.loc[i]
    if(target['중계열']=='치료ㆍ보건') :
        main_2021.loc[[i],['awareness']] = 10
    elif (target['중계열']=='응용예술') :
        main_2021.loc[[i],['awareness']] = 9
    elif (target['중계열']=='유아교육' or target['중계열']=='중등교육' or target['중계열']=='초등교육' or target['중계열']=='특수교육') :
        main_2021.loc[[i],['awareness']] = 8
    elif (target['대계열']=='공학계열') :
        main_2021.loc[[i],['awareness']] = 7
    elif (target['중계열']=='경영ㆍ경제') :
        main_2021.loc[[i],['awareness']] = 6
    elif (target['중계열']=='생물ㆍ화학ㆍ환경') :
        main_2021.loc[[i],['awareness']] = 5
    elif (target['중계열']=='사회과학') :
        main_2021.loc[[i],['awareness']] = 4
    elif (target['중계열']=='컴퓨터ㆍ통신') :
        main_2021.loc[[i],['awareness']] = 3
    elif (target['중계열']=='언어ㆍ문학') :
        main_2021.loc[[i],['awareness']] = 2
    elif (target['중계열']=='교육일반') :
        main_2021.loc[[i],['awareness']] = 1
    else :
            main_2021.loc[[i],['awareness']] = 0

# %%
df_2015 = pd.read_excel('/content/sample_data/2015_filtered.xlsx' , engine='openpyxl')
df_2016 = pd.read_excel('/content/sample_data/2016_filtered.xlsx' , engine='openpyxl')
df_2017 = pd.read_excel('/content/sample_data/2017_filtered.xlsx' , engine='openpyxl')
df_2018 = pd.read_excel('/content/sample_data/2018_filtered.xlsx' , engine='openpyxl')
df_2019 = pd.read_excel('/content/sample_data/2019_filtered.xlsx' , engine='openpyxl')
df_2020 = pd.read_excel('/content/sample_data/2020_filtered.xlsx' , engine='openpyxl')
df_2021 = pd.read_excel('/content/sample_data/2021_filtered.xlsx' , engine='openpyxl')

# %%
main_2015
# Out:
#          연도        학교명  시도    대계열    중계열       학과명  모집인원_학부_계  지원자_전체_계  \
# 0      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    국어국문학과         38       238
# 1      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    중어중문학과         27       154
# 2      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    영어영문학과         38       193
# 3      2015    강릉원주대학교  강원   인문계열  언어ㆍ문학    독어독문학과         23       118
# 4      2015    강릉원주대학교  강원   인문계열   인문과학       사학과         27       174
# ...     ...        ...  ..    ...    ...       ...        ...       ...
# 11879  2015  한국전통문화대학교  충남   인문계열   인문과학     보존과학과         21       139
# 11880  2015  한국전통문화대학교  충남   공학계열     건축    전통건축학과         21       126
# 11881  2015  한국전통문화대학교  충남   공학계열     건축    전통조경학과         21       100
# 11882  2015  한국전통문화대학교  충남  예체능계열   응용예술  전통미술공예학과         42       142
# 11883  2015  한국전통문화대학교  충남    NaN    NaN    소속학과없음          0         0
#
#        입학자_전체_계  Gov_Spnsorship  awareness
# 0            37               0          7
# ...

# %%
main_ = main_2015
df_ = df_2015

for i in range(len(main_)):
    for j in range(len(df_)):
        if(main_.iat[i,1] == df_.iat[j,1]):
            main_.iat[i,8] = df_.iat[j,2]

main_2015_com = main_

# %%
main_ = main_2016
df_ = df_2016

for i in range(len(main_)):
    for j in range(len(df_)):
        if(main_.iat[i,1] == df_.iat[j,1]):
            main_.iat[i,8] = df_.iat[j,2]

main_2016_com = main_

# %%
main_ = main_2017
df_ = df_2017

for i in range(len(main_)):
    for j in range(len(df_)):
        if(main_.iat[i,1] == df_.iat[j,1]):
            main_.iat[i,8] = df_.iat[j,2]

main_2017_com = main_

# %%
main_ = main_2018
df_ = df_2018

for i in range(len(main_)):
    for j in range(len(df_)):
        if(main_.iat[i,1] == df_.iat[j,1]):
            main_.iat[i,8] = df_.iat[j,2]

main_2018_com = main_

# %%
main_ = main_2019
df_ = df_2019

for i in range(len(main_)):
    for j in range(len(df_)):
        if(main_.iat[i,1] == df_.iat[j,1]):
            main_.iat[i,8] = df_.iat[j,2]

main_2019_com = main_

# %%
main_ = main_2020
df_ = df_2020

for i in range(len(main_)):
    for j in range(len(df_)):
        if(main_.iat[i,1] == df_.iat[j,1]):
            main_.iat[i,8] = df_.iat[j,2]

main_2020_com = main_

# %%
main_ = main_2021
df_ = df_2021

for i in range(len(main_)):
    for j in range(len(df_)):
        if(main_.iat[i,1] == df_.iat[j,1]):
            main_.iat[i,8] = df_.iat[j,2]

main_2021_com = main_

# %%
result = pd.concat([main_2015_com, main_2016_com, main_2017_com, main_2018_com, main_2019_com, main_2020_com, main_2021_com])

# %%
result.head(50)
# Out:
#       연도      학교명  시도   대계열          중계열                학과명  모집인원_학부_계  \
# 0   2015  강릉원주대학교  강원  인문계열        언어ㆍ문학             국어국문학과         38
# 1   2015  강릉원주대학교  강원  인문계열        언어ㆍ문학             중어중문학과         27
# 2   2015  강릉원주대학교  강원  인문계열        언어ㆍ문학             영어영문학과         38
# 3   2015  강릉원주대학교  강원  인문계열        언어ㆍ문학             독어독문학과         23
# 4   2015  강릉원주대학교  강원  인문계열         인문과학                사학과         27
# 5   2015  강릉원주대학교  강원  인문계열         인문과학               일본학과         29
# 6   2015  강릉원주대학교  강원  인문계열         인문과학                철학과         28
# 7   2015  강릉원주대학교  강원  인문계열         인문과학             기타모집단위         10
# 8   2015  강릉원주대학교  강원  사회계열        경영ㆍ경제               경영학과         43
# 9   2015  강릉원주대학교  강원  사회계열        경영ㆍ경제             관광경영학과         50
# 10  2015  강릉원주대학교  강원  사회계열        경영ㆍ경제               경제학과         40
# 11  2015  강릉원주대학교  강원  사회계열        경영ㆍ경제               회계학과         41
# ...

# %%
result.to_excel('merged_main_data_final.xlsx', index = False)
